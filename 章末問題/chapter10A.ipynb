# %% [markdown]
# # Jupyter Notebookで始めるプログラミング　演習問題　（１０章）

# %% [markdown]
# ## 10-1

# %%
import random
import math
import matplotlib.pyplot as plt

def next_step():
    if random.random() > .5:
        return 1
    else:
        return -1

# %%
pos = 0
pos_history = [] # 歩みを記録するリスト
for i in range(1000):
    pos += next_step()
    pos_history.append(pos) # リストに位置を記録する

plt.hist(pos_history,  rwidth = 0.9)
plt.show()

# %% [markdown]
# ## 10-2

# %%
def next_stepC():
    return random.random() * 2 - 1
pos = 0
pos_history = [] # 歩みを記録するリスト
for i in range(1000):
    pos += next_stepC()
    pos_history.append(pos) # リストに位置を記録する

plt.plot(pos_history)
plt.show()

# %% [markdown]
# ## 10-3

# %%
pos = 0
pos_history = [] # 歩みを記録するリスト
for i in range(1000):
    pos += next_stepC()
    pos_history.append(pos) # リストに位置を記録する

plt.hist(pos_history, rwidth = 0.9)
plt.show()

# %% [markdown]
# ## 10-4

# %%
def next_stepS(x):
    if (abs(x) < .1):
        return 2 - random.random()
    else:
        return - random.random() * 2 / x

# %% [markdown]
# 移動位置の履歴

# %%
pos = 0
pos_history = [] # 歩みを記録するリスト
for i in range(1000):
    pos += next_stepS(pos)
    pos_history.append(pos) # リストに位置を記録する

plt.plot(pos_history)
plt.show()

# %% [markdown]
# ヒストグラム

# %%
pos = 0
pos_history = [] # 歩みを記録するリスト
for i in range(1000):
    pos += next_stepS(pos)
    pos_history.append(pos) # リストに位置を記録する

plt.hist(pos_history, rwidth = 0.9)
plt.show()
