# %% [markdown]
# # Jupyter Notebookで始めるプログラミング　演習問題　（８章）

# %% [markdown]
# ##  8-1

# %%
cards = ["HA", "H2", "H3", "H4", "H5", "H6", "H7", "H8", "H9", "HJ", "HQ", "HK",
        "SA", "S2", "S3", "S4", "S5", "S6", "S7", "S8", "S9", "SJ", "SQ", "SK",
        "CA", "C2", "C3", "C4", "C5", "C6", "C7", "C8", "C9", "CJ", "CQ", "CK",
        "DA", "D2", "D3", "D4", "D5", "D6", "D7", "D8", "D9", "DJ", "DQ", "DK",
       "J"]

# %%
# 線形探索で任意のカードを探す
def findCard(c, l):
    i = 0
    while (i < len(l)):
        if l[i] == c:
            print("発見")
            break
        i += 1

# %%
import random
print(random.sample(cards, 13))
spl = random.sample(cards, 13)
spl
# Out:
# ['C3', 'D7', 'CJ', 'S7', 'DA', 'S4', 'SK', 'S5', 'H2', 'CA', 'HK', 'H6', 'H8']
# ['S3', 'C5', 'SQ', 'D9', 'C8', 'H3', 'D5', 'DK', 'H8', 'D8', 'H7', 'H2', 'SK']

# %%
findCard("HA",spl)

# %% [markdown]
# ##  8-2

# %% [markdown]
# 二分探索のプログラムを改造して、パラメータで与えた任意のカードがあるかどうか探すプログラム$findCard2()$を作成しなさい

# %%
# 二分探索で任意のカードを探す
def findCard2(c, l):
    min_idx = 0
    max_idx = len(l)
    while min_idx <= max_idx:
        mid_idx = int((min_idx + max_idx) / 2)
        if l[mid_idx] == c:
            print("発見")
            return
        if l[mid_idx] > c:
            max_idx = mid_idx-1
        else:
            min_idx = mid_idx+1
    return #未発見

# %%
spl.sort() # 予めソートしておく
spl
# Out:
# ['C5', 'C8', 'D5', 'D8', 'D9', 'DK', 'H2', 'H3', 'H7', 'H8', 'S3', 'SK', 'SQ']

# %%
findCard2("HA",spl)

# %% [markdown]
# ##  8-3

# %%
import random
random.choices(cards, k=1000)
# Out:
# ['D4',
#  'C6',
#  'D6',
#  'D9',
#  'D5',
#  'S7',
#  'C9',
#  'S7',
#  'HQ',
#  'DJ',
#  'DK',
#  'HQ',
#  'DJ',
#  'S9',
#  'H6',
#  'C4',
#  'C7',
#  'CK',
#  'H8',
#  'J',
#  'C8',
#  'HQ',
#  'C8',
#  'D8',
#  'S8',
#  'CJ',
#  'H3',
#  'DQ',
#  'C9',
#  'DK',
#  'SQ',
#  'SA',
#  'H7',
#  'S8',
#  'H6',
#  'SQ',
#  'S4',
#  'H5',
#  'SQ',
#  'H3',
#  'H3',
#  'D6',
#  'D3',
#  'D2',
#  'DJ',
#  'C6',
#  'HJ',
#  'HK',
#  'H9',
#  'C4',
#  'J',
#  'S4',
#  'D2',
#  'HJ',
#  'CK',
#  'S8',
#  'S6',
#  'DJ',
#  'D9',
#  'S3',
#  'C2',
#  'CJ',
#  'HK',
#  'SQ',
#  'SK',
#  'C5',
#  'D7',
#  'D9',
#  'C9',
#  'C4',
#  'C9',
#  'DK',
#  'CQ',
#  'DJ',
#  'H5',
#  'CQ',
#  'S2',
#  'C8',
#  'D7',
#  'HA',
#  'S4',
#  'DQ',
#  'H7',
#  'CA',
#  'H3',
#  'D2',
#  'SQ',
#  'SA',
#  'S5',
#  'D2',
#  'D7',
#  'H8',
#  'H5',
#  'S2',
#  'CJ',
#  'J',
#  'C8',
#  'DQ',
#  'DQ',
#  'S6',
#  'H8',
#  'D2',
#  'J',
#  'C8',
#  'D7',
#  'S5',
#  'C2',
#  'S4',
#  'CQ',
#  'J',
#  'C3',
#  'H8',
#  'H7',
#  'CJ',
#  'S5',
#  'H6',
#  'C3',
#  'SJ',
#  'SK',
#  'SQ',
#  'C4',
#  'H9',
#  'D9',
#  'D8',
#  'D5',
#  'D2',
#  'CJ',
#  'DQ',
#  'D8',
#  'C8',
#  'H6',
#  'H6',
#  'J',
#  'HK',
#  'CA',
#  'D4',
#  'C3',
#  'D5',
#  'C3',
#  'H7',
#  'J',
#  'C6',
#  'HJ',
#  'D9',
#  'HK',
#  'H7',
#  'D9',
#  'C7',
#  'H2',
#  'SQ',
#  'DA',
#  'C9',
#  'H8',
#  'SQ',
#  'HA',
#  'C6',
#  'HQ',
#  'H5',
#  'D4',
#  'SK',
#  'H4',
#  'CQ',
#  'C3',
#  'C7',
#  'D8',
#  'DQ',
#  'H3',
#  'S3',
#  'CQ',
#  'H3',
#  'C3',
#  'HJ',
#  'H7',
#  'S7',
#  'S3',
#  'CK',
#  'D6',
#  'D2',
#  'D3',
#  'S5',
#  'D5',
#  'C3',
#  'CA',
#  'S2',
#  'SJ',
#  'S3',
#  'C9',
#  'CA',
#  'HK',
#  'CJ',
#  'SQ',
#  'DA',
#  'H2',
#  'C2',
#  'DA',
#  'H7',
#  'C5',
#  'C5',
#  'H9',
#  'C7',
#  'HA',
#  'C5',
#  'DQ',
#  'SA',
#  'DA',
#  'S6',
#  'H2',
#  'D4',
#  'H7',
#  'HK',
#  'D9',
#  'SA',
#  'DQ',
#  'H2',
#  'HK',
#  'D2',
#  'S4',
#  'H6',
#  'J',
#  'S8',
#  'H2',
#  'HA',
#  'H6',
#  'H9',
#  'SA',
#  'C9',
#  'D5',
#  'H2',
#  'HJ',
#  'H7',
#  'C2',
#  'D4',
#  'D6',
#  'CK',
#  'HJ',
#  'D9',
#  'CK',
#  'D6',
#  'HJ',
#  'H5',
#  'S6',
#  'H2',
#  'H7',
#  'SA',
#  'D7',
#  'S5',
#  'SA',
#  'C6',
#  'C8',
#  'D7',
#  'H5',
#  'H8',
#  'J',
#  'S6',
#  'C8',
#  'CQ',
#  'D9',
#  'H9',
#  'J',
#  'SK',
#  'S3',
#  'S7',
#  'H8',
#  'CQ',
#  'S3',
#  'C6',
#  'D9',
#  'C2',
#  'D7',
#  'S5',
#  'C7',
#  'S5',
#  'H4',
#  'J',
#  'C6',
#  'HK',
#  'S2',
#  'C8',
#  'H3',
#  'H7',
#  'CA',
#  'CK',
#  'SK',
#  'S9',
#  'D5',
#  'H6',
#  'S8',
#  'D4',
#  'C6',
#  'DK',
#  'S8',
#  'J',
#  'S9',
#  'SK',
#  'C5',
#  'H8',
#  'D8',
#  'SJ',
#  'DK',
#  'S7',
#  'S6',
#  'HQ',
#  'H4',
#  'H6',
#  'DK',
#  'HA',
#  'SQ',
#  'D4',
#  'C4',
#  'DJ',
#  'CQ',
#  'CQ',
#  'D7',
#  'S6',
#  'S6',
#  'D8',
#  'S4',
#  'D8',
#  'C6',
#  'S4',
#  'DA',
#  'C4',
#  'SQ',
#  'D5',
#  'S7',
#  'SJ',
#  'S8',
#  'DJ',
#  'S2',
#  'CK',
#  'D5',
#  'S6',
#  'S7',
#  'D5',
#  'H2',
#  'H9',
#  'H5',
#  'CK',
#  'SQ',
#  'D7',
#  'CA',
#  'D9',
#  'H3',
#  'CK',
#  'D6',
#  'D7',
#  'S8',
#  'DQ',
#  'H5',
#  'C2',
#  'C4',
#  'D2',
#  'D3',
#  'HQ',
#  'C7',
#  'SQ',
#  'S5',
#  'H5',
#  'C6',
#  'C6',
#  'H6',
#  'H6',
#  'DQ',
#  'C8',
#  'S4',
#  'S3',
#  'S3',
#  'C2',
#  'C2',
#  'S7',
#  'DA',
#  'DK',
#  'DA',
#  'HJ',
#  'S3',
#  'S4',
#  'HQ',
#  'CQ',
#  'DA',
#  'C7',
#  'CA',
#  'D9',
#  'CA',
#  'C2',
#  'DQ',
#  'S6',
#  'CA',
#  'H2',
#  'HQ',
#  'SA',
#  'S3',
#  'D6',
#  'D3',
#  'D8',
#  'HK',
#  'C5',
#  'CK',
#  'C6',
#  'C2',
#  'DA',
#  'HQ',
#  'CJ',
#  'H7',
#  'D6',
#  'S9',
#  'H5',
#  'S2',
#  'DA',
#  'D9',
#  'SA',
#  'D6',
#  'D3',
#  'D9',
#  'C2',
#  'D9',
#  'D7',
#  'D4',
#  'D6',
#  'DA',
#  'CK',
#  'H9',
#  'DQ',
#  'H6',
#  'H4',
#  'HK',
#  'S7',
#  'H5',
#  'D6',
#  'H2',
#  'H9',
#  'CK',
#  'H2',
#  'SJ',
#  'S7',
#  'SQ',
#  'HJ',
#  'S6',
#  'H2',
#  'CJ',
#  'D3',
#  'SJ',
#  'DJ',
#  'SK',
#  'HJ',
#  'HA',
#  'C9',
#  'C4',
#  'HQ',
#  'H6',
#  'S4',
#  'D5',
#  'HK',
#  'D8',
#  'C3',
#  'H4',
#  'H2',
#  'DA',
#  'H6',
#  'H4',
#  'CK',
#  'SK',
#  'CA',
#  'D2',
#  'CA',
#  'S3',
#  'H4',
#  'C3',
#  'HA',
#  'C4',
#  'S8',
#  'H2',
#  'CA',
#  'H5',
#  'C7',
#  'D8',
#  'D2',
#  'H6',
#  'H5',
#  'HK',
#  'D3',
#  'H5',
#  'H8',
#  'C5',
#  'H2',
#  'H7',
#  'C8',
#  'C9',
#  'SQ',
#  'CK',
#  'D8',
#  'S4',
#  'J',
#  'DQ',
#  'DK',
#  'S4',
#  'H8',
#  'HJ',
#  'CK',
#  'HK',
#  'D4',
#  'S8',
#  'C3',
#  'D4',
#  'S5',
#  'C3',
#  'S2',
#  'D2',
#  'SK',
#  'D9',
#  'J',
#  'C6',
#  'S3',
#  'SK',
#  'H9',
#  'D5',
#  'SJ',
#  'D4',
#  'D7',
#  'H7',
#  'C2',
#  'D9',
#  'H2',
#  'DA',
#  'CJ',
#  'CQ',
#  'HA',
#  'D6',
#  'H6',
#  'DJ',
#  'S9',
#  'H2',
#  'D5',
#  'C9',
#  'CQ',
#  'SA',
#  'C7',
#  'H6',
#  'CJ',
#  'J',
#  'S8',
#  'C4',
#  'HJ',
#  'D2',
#  'C8',
#  'HA',
#  'C2',
#  'HA',
#  'SK',
#  'HJ',
#  'C9',
#  'C3',
#  'HA',
#  'CK',
#  'DA',
#  'H7',
#  'HQ',
#  'S4',
#  'C3',
#  'C8',
#  'HQ',
#  'C4',
#  'C4',
#  'C5',
#  'HQ',
#  'SJ',
#  'S8',
#  'CJ',
#  'DQ',
#  'C2',
#  'C3',
#  'D8',
#  'SK',
#  'H4',
#  'C2',
#  'HJ',
#  'H9',
#  'S5',
#  'SK',
#  'DK',
#  'S5',
#  'C8',
#  'DK',
#  'D6',
#  'HA',
#  'C3',
#  'D4',
#  'DJ',
#  'H4',
#  'DQ',
#  'S2',
#  'SA',
#  'H3',
#  'C9',
#  'H8',
#  'DJ',
#  'H9',
#  'C4',
#  'D5',
#  'J',
#  'H9',
#  'H8',
#  'S8',
#  'C6',
#  'CQ',
#  'J',
#  'D8',
#  'D2',
#  'H8',
#  'D8',
#  'C5',
#  'S2',
#  'H3',
#  'S9',
#  'C3',
#  'SJ',
#  'SK',
#  'DK',
#  'SA',
#  'H9',
#  'SJ',
#  'DA',
#  'H8',
#  'H4',
#  'S7',
#  'HQ',
#  'D8',
#  'HK',
#  'D9',
#  'D8',
#  'D2',
#  'SA',
#  'C2',
#  'SA',
#  'D6',
#  'SA',
#  'H4',
#  'S9',
#  'HJ',
#  'CK',
#  'CA',
#  'S4',
#  'J',
#  'CA',
#  'HA',
#  'S8',
#  'H8',
#  'HQ',
#  'C3',
#  'CJ',
#  'S9',
#  'H6',
#  'DJ',
#  'S7',
#  'C8',
#  'DQ',
#  'HA',
#  'CK',
#  'D5',
#  'S2',
#  'S2',
#  'H3',
#  'CK',
#  'SA',
#  'H5',
#  'SK',
#  'HK',
#  'H9',
#  'D9',
#  'S3',
#  'S9',
#  'S4',
#  'SQ',
#  'DA',
#  'SK',
#  'HJ',
#  'C9',
#  'S4',
#  'D4',
#  'HA',
#  'DJ',
#  'CJ',
#  'D4',
#  'D7',
#  'SK',
#  'CJ',
#  'D5',
#  'D7',
#  'C5',
#  'CA',
#  'C4',
#  'C7',
#  'HA',
#  'SQ',
#  'D7',
#  'D5',
#  'H8',
#  'D7',
#  'S7',
#  'CA',
#  'SA',
#  'D5',
#  'SK',
#  'H6',
#  'SJ',
#  'DK',
#  'SK',
#  'H6',
#  'HQ',
#  'HJ',
#  'S8',
#  'C3',
#  'C2',
#  'S6',
#  'SA',
#  'CA',
#  'D3',
#  'S2',
#  'D5',
#  'D4',
#  'H9',
#  'H9',
#  'SA',
#  'D3',
#  'C8',
#  'H2',
#  'CA',
#  'D4',
#  'CA',
#  'H7',
#  'D6',
#  'SA',
#  'S8',
#  'H5',
#  'D6',
#  'CA',
#  'DA',
#  'H5',
#  'D9',
#  'S6',
#  'H5',
#  'C6',
#  'C5',
#  'H9',
#  'C9',
#  'C4',
#  'H7',
#  'DA',
#  'D3',
#  'D4',
#  'SA',
#  'D6',
#  'D2',
#  'HA',
#  'D2',
#  'CK',
#  'D9',
#  'D7',
#  'S2',
#  'C7',
#  'HK',
#  'H6',
#  'DK',
#  'SK',
#  'CJ',
#  'H9',
#  'S4',
#  'HK',
#  'S2',
#  'HJ',
#  'SJ',
#  'HK',
#  'H8',
#  'D2',
#  'C2',
#  'D6',
#  'H5',
#  'CQ',
#  'DQ',
#  'CQ',
#  'DJ',
#  'DK',
#  'CQ',
#  'CQ',
#  'CJ',
#  'H7',
#  'C7',
#  'H9',
#  'H2',
#  'S9',
#  'C8',
#  'H4',
#  'D3',
#  'SJ',
#  'HA',
#  'DQ',
#  'H2',
#  'C7',
#  'DA',
#  'HA',
#  'H8',
#  'D2',
#  'C8',
#  'CK',
#  'CQ',
#  'DQ',
#  'DQ',
#  'SQ',
#  'H6',
#  'S3',
#  'H6',
#  'C4',
#  'S8',
#  'C5',
#  'SJ',
#  'C4',
#  'DA',
#  'S6',
#  'SQ',
#  'H6',
#  'S5',
#  'S2',
#  'DA',
#  'J',
#  'DA',
#  'S6',
#  'D6',
#  'S5',
#  'D3',
#  'CJ',
#  'H3',
#  'D8',
#  'D4',
#  'D5',
#  'D8',
#  'HA',
#  'C6',
#  'H6',
#  'C2',
#  'H9',
#  'C2',
#  'D3',
#  'D8',
#  'HQ',
#  'D3',
#  'D7',
#  'D7',
#  'D3',
#  'DA',
#  'D3',
#  'H8',
#  'C9',
#  'C8',
#  'C4',
#  'H6',
#  'H8',
#  'H2',
#  'S2',
#  'D9',
#  'SA',
#  'C3',
#  'S4',
#  'C6',
#  'C3',
#  'H8',
#  'D9',
#  'H4',
#  'D6',
#  'D4',
#  'HJ',
#  'D4',
#  'DA',
#  'S8',
#  'HJ',
#  'H4',
#  'C2',
#  'SA',
#  'J',
#  'H8',
#  'C9',
#  'SQ',
#  'HQ',
#  'DA',
#  'H7',
#  'H6',
#  'C7',
#  'CK',
#  'C7',
#  'DK',
#  'C9',
#  'H5',
#  'C4',
#  'C3',
#  'C6',
#  'D5',
#  'DJ',
#  'C2',
#  'C7',
#  'D7',
#  'D8',
#  'S2',
#  'C3',
#  'H2',
#  'SJ',
#  'CJ',
#  'HQ',
#  'SA',
#  'H5',
#  'J',
#  'D9',
#  'D4',
#  'DJ',
#  'S6',
#  'DK',
#  'C9',
#  'H8',
#  'S8',
#  'DQ',
#  'H5',
#  'D8',
#  'HQ',
#  'C8',
#  'C6',
#  'SA',
#  'S2',
#  'S4',
#  'C7',
#  'D6',
#  'H7',
#  'D7',
#  'S2',
#  'S7',
#  'S3',
#  'D7',
#  'S8',
#  'H2',
#  'DJ',
#  'C9',
#  'CA',
#  'DK',
#  'C3',
#  'HK',
#  'CJ',
#  'DJ',
#  'DA',
#  'H5',
#  'SJ',
#  'J',
#  'S8',
#  'D5',
#  'H2',
#  'D3',
#  'C2',
#  'CK',
#  'H8',
#  'D2',
#  'C7',
#  'CJ',
#  'CK',
#  'D2',
#  'S2',
#  'S4',
#  'DA',
#  'S6',
#  'C3',
#  'H2',
#  'C2',
#  'S2',
#  'H8',
#  'S5',
#  'HK',
#  'S3',
#  'DK',
#  'CA',
#  'D6',
#  'D5',
#  'DK',
#  'S6',
#  'DA',
#  'C8',
#  'C9',
#  'DQ',
#  'SQ',
#  'C3',
#  'H4',
#  'C3',
#  'D9',
#  'S8',
#  'SJ',
#  'CQ',
#  'HQ',
#  'C7',
#  'SK',
#  'SQ',
#  'C5',
#  'DA',
#  'S3',
#  'DQ',
#  'DK',
#  'S7',
#  'C7']

# %%
# 線形探索
def findJ(l):
    i = 0
    while (i < len(l)):
        if l[i] == "J":
            print("発見")
            break
        i += 1

# %%
# 二分探索
def findJ2(l):
    min_idx = 0
    max_idx = len(l)-1
    while min_idx <= max_idx:
        mid_idx = int((min_idx + max_idx) / 2)
        if l[mid_idx] == "J":
            print("発見")
            return
        if l[mid_idx] > "J":
            max_idx = mid_idx-1
        else:
            min_idx = mid_idx+1
    return # 未発見

# %%
f = random.choices(cards, k=50000000)

# %time
findJ(f)
# Out:
# CPU times: user 1e+03 ns, sys: 0 ns, total: 1e+03 ns
# Wall time: 3.81 µs
# 発見

# %%
f.sort()
# %time
findJ2(f)
# Out:
# CPU times: user 1 µs, sys: 0 ns, total: 1 µs
# Wall time: 4.05 µs
# 発見

# %% [markdown]
# ## 8-4 略
